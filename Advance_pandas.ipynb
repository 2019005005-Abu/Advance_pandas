# %%
import numpy as np;
import matplotlib.pyplot as plt;
import pandas as pd;
import torch as tr;
print(tr.__version__)
# Out:
# 2.6.0+cu124

# %% [markdown]
# # New section

# %%
data_set_path='/content/drive/MyDrive/data_set/train.csv'
df=pd.read_csv(data_set_path)
df.head(20)
df[['Name','Sex','Age']]
df
df[(df['Age']>60)& (df['Sex']=='female')]
df.shape
# Out:
# (891, 12)

# %%
df.loc[200:210,['Name','Sex']]
df
df.loc[260:300,['Name','Survived','Sex']]
# Out:
#                                                 Name  Survived     Sex
# 260                                Smith, Mr. Thomas         0    male
# 261                Asplund, Master. Edvin Rojj Felix         1    male
# 262                                Taussig, Mr. Emil         0    male
# 263                            Harrison, Mr. William         0    male
# 264                               Henry, Miss. Delia         0  female
# 265                                Reeves, Mr. David         0    male
# 266                        Panula, Mr. Ernesti Arvid         0    male
# 267                         Persson, Mr. Ernst Ulrik         1    male
# 268    Graham, Mrs. William Thompson (Edith Junkins)         1  female
# 269                           Bissette, Miss. Amelia         1  female
# 270                            Cairns, Mr. Alexander         0    male
# 271                     Tornquist, Mr. William Henry         1    male
# ...

# %%
##Query in Pandas
df.query("Age>60 and Sex=='female' and Parch==0")
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 275          276         1       1          Andrews, Miss. Kornelia Theodosia
# 483          484         1       3                     Turkula, Mrs. (Hedwig)
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 275  female  63.0      1      0   13502  77.9583    D7        S
# 483  female  63.0      0      0    4134   9.5875   NaN        S
# 829  female  62.0      0      0  113572  80.0000   B28      NaN

# %%
df
df.groupby('Pclass')['Age'].count()
# Out:
# Pclass
# 1    186
# 2    173
# 3    355
# Name: Age, dtype: int64

# %%
df
df.groupby('Pclass')['Survived'].count()###Survived
# Out:
# Pclass
# 1    214
# 2    184
# 3    491
# Name: Survived, dtype: int64

# %%
Missing_data=df.isnull().sum()
Missing_data
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# sex_number     0
# dtype: int64

# %%
df['sex_number']=df['Sex'].map({
  'male':0,
  'female':1
})
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked  sex_number
# 0      0         A/5 21171   7.2500        S           0
# 1      0          PC 17599  71.2833        C           1
# 2      0  STON/O2. 3101282   7.9250        S           1
# 3      0            113803  53.1000        S           1
# ...

# %%
df
df.shape
df=df.dropna(subset=['Embarked'])
df
df.shape
Missing_data=df.isnull().sum();
Missing_data
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# sex_number     0
# dtype: int64

# %%
# df=df.drop(['Cabin'],axis=1)
df['Age']=df['Age'].fillna(df['Age'].mean())
Missing_data=df.isnull().sum();
Missing_data
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# sex_number     0
# dtype: int64

# %%
Mean=df['Age']=df['Age'].fillna(df['Age'].mean())
Meadain=df['Age']=df['Age'].fillna(df['Age'].median())
Mod=df['Age'] = df['Age'].fillna(df['Age'].mode())

print(f'Mean-Value: {Mean}')
print(f'Meadain-Value: {Meadain}')
print(f'Mod-Value: {Mod}')
# Out:
# Mean-Value: 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.642093
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 889, dtype: float64
# Meadain-Value: 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.642093
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 889, dtype: float64
# Mod-Value: 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.642093
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 889, dtype: float64
